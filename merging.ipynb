# %%
import pandas as pd

# %%
pd_movies = pd.read_csv('IMDb movies.csv', low_memory=False)

# %%
pd_movies.head(3)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
#
#    year date_published                    genre  duration           country  \
# 0  1894     1894-10-09                  Romance        45               USA
# 1  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                    Drama        53  Germany, Denmark
#
#   language         director  ...  \
# 0      NaN  Alexander Black  ...
# 1      NaN     Charles Tait  ...
# 2      NaN        Urban Gad  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
# ...

# %%
pd_ratings = pd.read_csv('IMDb ratings.csv')

# %%
pd_ratings
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000009                    5.9          154        5.9
# 1         tt0000574                    6.1          589        6.3
# 2         tt0001892                    5.8          188        6.0
# 3         tt0002101                    5.2          446        5.3
# 4         tt0002130                    7.0         2237        6.9
# ...             ...                    ...          ...        ...
# 85850     tt9908390                    5.3          398        5.5
# 85851     tt9911196                    7.7          724        7.9
# 85852     tt9911774                    7.9          265        7.8
# 85853     tt9914286                    6.4          194        9.4
# 85854     tt9914942                    6.7          102        6.8
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        12        4       10       43       28  ...
# ...

# %%
pd_ratings.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6',
#        'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
# ...

# %%
pd_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
pd_movies = pd_movies[['imdb_title_id', 'title', 'year', 'genre', 'country']]

# %%
pd_ratings = pd_ratings[['imdb_title_id', 'total_votes', 'mean_vote']]

# %%
pd_movies
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# ...

# %%
pd_ratings
# Out:
#       imdb_title_id  total_votes  mean_vote
# 0         tt0000009          154        5.9
# 1         tt0000574          589        6.3
# 2         tt0001892          188        6.0
# 3         tt0002101          446        5.3
# 4         tt0002130         2237        6.9
# ...             ...          ...        ...
# 85850     tt9908390          398        5.5
# 85851     tt9911196          724        7.9
# 85852     tt9911774          265        7.8
# 85853     tt9914286          194        9.4
# 85854     tt9914942          102        6.8
#
# [85855 rows x 3 columns]

# %%
pd_movies_half = pd_movies.sample(frac=0.5)

# %%
pd_movies_half.shape
# Out:
# (42928, 5)

# %%
df_concat = pd.concat([pd_movies, pd_movies_half], ignore_index=True)

# %%
df_concat
# Out:
#        imdb_title_id                        title  year  \
# 0          tt0000009                   Miss Jerry  1894
# 1          tt0000574  The Story of the Kelly Gang  1906
# 2          tt0001892               Den sorte drøm  1911
# 3          tt0002101                    Cleopatra  1912
# 4          tt0002130                    L'Inferno  1911
# ...              ...                          ...   ...
# 128778     tt2938066              The Midnighters  2016
# 128779     tt0032049                 L'usurpatore  1939
# 128780     tt6504868                        Sadie  2018
# 128781     tt0371092              Pour le plaisir  2004
# 128782     tt0080342          Attori di provincia  1979
#
#                             genre              country
# 0                         Romance                  USA
# 1         Biography, Crime, Drama            Australia
# 2                           Drama     Germany, Denmark
# 3                  Drama, History                  USA
# ...

# %%
df_concat.shape
# Out:
# (128783, 5)

# %%
df_movies_combine = pd.concat([pd_movies.set_index('imdb_title_id'), pd_ratings.set_index('imdb_title_id')], axis=1)

# %%
df_movies_combine
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country  total_votes  \
# imdb_title_id
# tt0000009                        Romance               USA          154
# tt0000574        Biography, Crime, Drama         Australia          589
# tt0001892                          Drama  Germany, Denmark          188
# ...

# %%
df_movies_combine.reset_index(inplace=True)

# %%
df_movies_combine
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %%
df1 = pd.DataFrame({'id': ['A', 'B', 'C', 'D'],
                    'age': [30, 23, 25, 22]})
df2 = pd.DataFrame({'id': ['C', 'D', 'E', 'F'],
                    'job': ['Doctor', 'Statistician',
                            'Accountant', 'Developer']})

# %%
df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2
# Out:
#   id           job
# 0  C        Doctor
# 1  D  Statistician
# 2  E    Accountant
# 3  F     Developer

# %%
df_inner = df1.merge(df2, on='id', how='inner')

# %%
df_inner
# Out:
#   id  age           job
# 0  C   25        Doctor
# 1  D   22  Statistician

# %%
df_inner.shape
# Out:
# (2, 3)

# %%
df_movies_combine = pd_movies.merge(pd_ratings, on='imdb_title_id', how='inner')

# %%
df_movies_combine
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %%
df_movies_combine.shape
# Out:
# (85855, 7)

# %%
df_outer = df1.merge(df2, on='id', how='outer')

# %%
df_outer
# Out:
#   id   age           job
# 0  A  30.0           NaN
# 1  B  23.0           NaN
# 2  C  25.0        Doctor
# 3  D  22.0  Statistician
# 4  E   NaN    Accountant
# 5  F   NaN     Developer

# %%
df_movies_combine = pd_movies.merge(pd_ratings, on='imdb_title_id', how='outer')

# %%
df_movies_combine
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %%
df_outer = df1.merge(df2, on='id', how='outer', indicator=True)

# %%
df_outer
# Out:
#   id   age           job      _merge
# 0  A  30.0           NaN   left_only
# 1  B  23.0           NaN   left_only
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
df_outer = df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='left_only'")

# %%
df_outer
# Out:
#   id   age  job     _merge
# 0  A  30.0  NaN  left_only
# 1  B  23.0  NaN  left_only

# %%
df_outer = df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='right_only'")

# %%
df_outer
# Out:
#   id  age         job      _merge
# 4  E  NaN  Accountant  right_only
# 5  F  NaN   Developer  right_only

# %%
df_outer = df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='right_only' or _merge=='left_only'")

# %%
df_outer
# Out:
#   id   age         job      _merge
# 0  A  30.0         NaN   left_only
# 1  B  23.0         NaN   left_only
# 4  E   NaN  Accountant  right_only
# 5  F   NaN   Developer  right_only

# %%
pd_movies.merge(pd_ratings, on='imdb_title_id', how='outer', indicator=True).query("_merge=='right_only' or _merge=='left_only'")
# Out:
# Empty DataFrame
# Columns: [imdb_title_id, title, year, genre, country, total_votes, mean_vote, _merge]
# Index: []

# %%
df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='both' or _merge=='left_only'")
# Out:
#   id   age           job     _merge
# 0  A  30.0           NaN  left_only
# 1  B  23.0           NaN  left_only
# 2  C  25.0        Doctor       both
# 3  D  22.0  Statistician       both

# %%
df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='both' or _merge=='right_only'")
# Out:
#   id   age           job      _merge
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
df1.merge(df2, on='id', how='right')
# Out:
#   id   age           job
# 0  C  25.0        Doctor
# 1  D  22.0  Statistician
# 2  E   NaN    Accountant
# 3  F   NaN     Developer

# %%
df1.merge(df2, on='id', how='left')
# Out:
#   id  age           job
# 0  A   30           NaN
# 1  B   23           NaN
# 2  C   25        Doctor
# 3  D   22  Statistician
